# %%
# from collections import OrderedDict
# from collections import OrderedDict 
import collections
ans = set() 
nums = [-1,0,1,2,-1,-4]
if len(nums) < 3: print(ans) 
if nums.count(0) >= 3: ans.add((0,0,0)) 
nums_set = set(nums)
numMax, numMin = max(nums_set), min(nums_set)
if numMax <= 0 or numMin >= 0: print( ans)
setP = set(num for num in nums_set if (num > 0 and num <= -2 * numMin))
setN = set(num for num in nums_set if (num < 0 and num >= -2 * numMax)) 
count = collections.Counter(nums)

for numP in setP:
    for numN in setN:
        numD=-numP-numN
        if numD in nums_set:
            val=tuple(sorted([numD,numP,numN]))
            print(val)
            print(val.count(numD))
            if val.count(numD)<=count[numD] and val.count(numP)<=count[numP] and val.count(numN)<=count[numN]:
                ans.add(val)
print(ans)
# Out:
# <generator object <genexpr> at 0x000001C7D458DCC8>
# (-1, 0, 1)
# 1
# (-4, 2, 2)
# 2
# (-1, -1, 2)
# 2
# {(-1, -1, 2), (-1, 0, 1)}

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# _cffi_ext.c
# C:\Users\91812\anaconda3\lib\site-packages\zmq\backend\cffi\__pycache__\_cffi_ext.c(266): fatal error C1083: Cannot open include file: 'sys/un.h': No such file or directory
# Crypto              brain_uuid          menuinst            snowballstemmer
# Cython              bs4                 mimetypes           socket
# IPython             bson                mistune             socketserver
# OpenSSL             builtins            mkl                 socks
# PIL                 bz2                 mkl_fft             sockshandler
# PyQt5               cProfile            mkl_random          sortedcollections
# __future__          calendar            mmap                sortedcontainers
# _abc                certifi             mmapfile            soupsieve
# _ast                cffi                mmsystem            sphinx
# _asyncio            cgi                 mock                sphinxcontrib
# _bisect             cgitb               modulefinder        sphinxify
# _blake2             chardet             more_itertools      sphinxthread
# _bootlocale         chunk               mpmath              spyder
# _bz2                click               msgpack             spyder_kernels
# _cffi_backend       cloudpickle         msilib              sqlalchemy
# _codecs             clyent              msvcrt              sqlite3
# _codecs_cn          cmath               multipledispatch    sre_compile
# _codecs_hk          cmd                 multiprocessing     sre_constants
# _codecs_iso2022     code                multitasking        sre_parse
# _codecs_jp          codecs              nacl                ssl
# _codecs_kr          codeop              navigator_updater   sspi
# _codecs_tw          collections         nbconvert           sspicon
# _collections        colorama            nbformat            stat
# _collections_abc    colorsys            netbios             statistics
# _compat_pickle      commctrl            netrc               statsmodels
# _compression        compileall          networkx            storemagic
# _contextvars        comtypes            nltk                string
# _csv                concurrent          nntplib             stringprep
# _ctypes             conda               nose                struct
# _ctypes_test        conda_build         notebook            subprocess
# _datetime           conda_env           nt                  sunau
# _decimal            conda_package_handling ntpath              symbol
# _dummy_thread       conda_verify        ntsecuritycon       sympy
# _elementtree        conf                nturl2path          sympyprinting
# _functools          configparser        numba               symtable
# _hashlib            contextlib          numbers             sys
# _heapq              contextlib2         numexpr             sysconfig
# _imp                contextvars         numpy               tables
# _io                 copy                numpydoc            tabnanny
# _json               copyreg             odbc                tarfile
# _locale             crypt               olefile             tblib
# _lsprof             cryptography        opcode              telnetlib
# _lzma               csv                 openpyxl            tempfile
# _markupbase         ctypes              operator            terminado
# _md5                curl                optparse            test
# _msi                curses              os                  test_data
# _multibytecodec     cwp                 packaging           test_pycosat
# _multiprocessing    cycler              pandas              testpath
# _nsis               cython              pandas_datareader   tests
# _opcode             cythonmagic         pandocfilters       textwrap
# _operator           cytoolz             paramiko            this
# _osx_support        dask                parser              threading
# _overlapped         dataclasses         parso               time
# _pickle             datetime            partd               timeit
# _py_abc             dateutil            past                timer
# _pydecimal          dbi                 path                tkinter
# _pyio               dbm                 pathlib             tlz
# _pylief             dde                 pathlib2            token
# _pyrsistent_version decimal             pathtools           tokenize
# _pytest             decorator           patsy               toolz
# _queue              defusedxml          pdb                 tornado
# _random             diff_match_patch    pep8                tqdm
# _sha1               difflib             perfmon             trace
# _sha256             dis                 pexpect             traceback
# _sha3               distributed         pickle              tracemalloc
# _sha512             distutils           pickleshare         traitlets
# _signal             doctest             pickletools         tty
# _sitebuiltins       docutils            pip                 turtle
# _socket             dummy_threading     pipes               turtledemo
# _sqlite3            easy_install        pkg_resources       types
# _sre                email               pkginfo             typing
# _ssl                encodings           pkgutil             ujson
# _stat               ensurepip           platform            unicodecsv
# _string             entrypoints         plistlib            unicodedata
# _strptime           enum                pluggy              unittest
# _struct             errno               ply                 urllib
# _symtable           et_xmlfile          poplib              urllib3
# _system_path        fastcache           posixpath           uu
# _testbuffer         faulthandler        pprint              uuid
# _testcapi           filecmp             profile             venv
# _testconsole        fileinput           prometheus_client   warnings
# _testimportmultiple filelock            prompt_toolkit      watchdog
# _testmultiphase     flake8              pstats              wave
# _thread             flask               psutil              wcwidth
# _threading_local    fnmatch             pty                 weakref
# _tkinter            formatter           pvectorc            webbrowser
# _tracemalloc        fractions           py                  webencodings
# _warnings           fsspec              py_compile          werkzeug
# _weakref            ftplib              pyclbr              wheel
# _weakrefset         functools           pycodestyle         widgetsnbextension
# _win32sysloader     future              pycosat             win2kras
# _winapi             gc                  pycparser           win32api
# _winxptheme         genericpath         pycurl              win32clipboard
# _yaml               getopt              pydoc               win32com
# abc                 getpass             pydoc_data          win32con
# adodbapi            gettext             pydocstyle          win32console
# afxres              gevent              pyexpat             win32cred
# aifc                glob                pyflakes            win32crypt
# alabaster           glob2               pygments            win32cryptcon
# anaconda_navigator  greenlet            pylab               win32ctypes
# anaconda_project    gridfs              pylint              win32event
# antigravity         gzip                pyls                win32evtlog
# argh                h5py                pyls_jsonrpc        win32evtlogutil
# argparse            hashlib             pymongo             win32file
# array               heapdict            pyodbc              win32gui
# asn1crypto          heapq               pyparsing           win32gui_struct
# ast                 hmac                pyreadline          win32help
# astroid             html                pyrsistent          win32inet
# astropy             html5lib            pytest              win32inetcon
# asynchat            http                pytest_arraydiff    win32job
# asyncio             hypothesis          pytest_astropy_header win32lz
# asyncore            idlelib             pytest_doctestplus  win32net
# atexit              idna                pytest_openfiles    win32netcon
# atomicwrites        imageio             pytest_remotedata   win32pdh
# attr                imagesize           pythoncom           win32pdhquery
# audioop             imaplib             pytz                win32pdhutil
# autopep8            imghdr              pywin               win32pipe
# autoreload          imp                 pywin32_bootstrap   win32print
# babel               importlib           pywin32_testutil    win32process
# backcall            importlib_metadata  pywintypes          win32profile
# backports           inflection          pywt                win32ras
# base64              inspect             pyximport           win32rcparser
# bcrypt              intervaltree        qdarkstyle          win32security
# bdb                 io                  qtawesome           win32service
# binascii            ipaddress           qtconsole           win32serviceutil
# binhex              ipykernel           qtpy                win32timezone
# binstar_client      ipykernel_launcher  quandl              win32trace
# bisect              ipython_genutils    queue               win32traceutil
# bitarray            ipywidgets          quopri              win32transaction
# bkcharts            isapi               random              win32ts
# bleach              isort               rasutil             win32ui
# bokeh               isympy              re                  win32uiole
# boto                itertools           readline            win32verstamp
# bottleneck          itsdangerous        regcheck            win32wnet
# brain_argparse      jdcal               regutil             win_inet_pton
# brain_attrs         jedi                reprlib             win_unicode_console
# brain_builtin_inference jinja2              requests            wincertstore
# brain_collections   joblib              rlcompleter         winerror
# brain_crypt         json                rmagic              winioctlcon
# brain_curses        json5               rope                winnt
# brain_dataclasses   jsonschema          rtree               winperf
# brain_dateutil      jupyter             ruamel_yaml         winpty
# brain_fstrings      jupyter_client      run                 winreg
# brain_functools     jupyter_console     runpy               winsound
# brain_gi            jupyter_core        sched               winxpgui
# brain_hashlib       jupyterlab          scipy               winxptheme
# brain_http          jupyterlab_server   scripts             wrapt
# brain_io            keyring             seaborn             wsgiref
# brain_mechanize     keyword             secrets             xdrlib
# brain_multiprocessing kiwisolver          select              xlrd
# brain_namedtuple_enum lazy_object_proxy   selectors           xlsxwriter
# brain_nose          lib2to3             send2trash          xlwings
# brain_numpy_core_fromnumeric libarchive          servicemanager      xlwt
# brain_numpy_core_function_base libfuturize         setuptools          xml
# brain_numpy_core_multiarray libpasteurize       shelve              xmlrpc
# brain_numpy_core_numeric lief                shlex               xmltodict
# brain_numpy_core_numerictypes linecache           shutil              xxsubtype
# brain_numpy_core_umath llvmlite            signal              yaml
# brain_numpy_ndarray locale              simplegeneric       yapf
# brain_numpy_random_mtrand locket              singledispatch      yapftests
# brain_numpy_utils   logging             singledispatch_helpers yfinance
# brain_pkg_resources lxml                sip                 zict
# brain_pytest        lzma                sipconfig           zipapp
# brain_qt            macpath             sipdistutils        zipfile
# brain_random        mailbox             site                zipimport
# brain_re            mailcap             six                 zipp
# brain_six           markupsafe          skimage             zlib
# brain_ssl           marshal             sklearn             zmq
# brain_subprocess    math                smtpd
# brain_threading     matplotlib          smtplib
# brain_typing        mccabe              sndhdr
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
